# %%
import pandas as pd

df = pd.read_csv("hf://datasets/OmegaYoel/Student_Performance/student_performance_prediction (2).csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Student ID                                   40000 non-null  object
#  1   Study Hours per Week                         38005 non-null  float64
#  2   Attendance Rate                              38008 non-null  float64
#  3   Previous Grades                              38006 non-null  float64
#  4   Participation in Extracurricular Activities  38000 non-null  object
#  5   Parent Education Level                       38000 non-null  object
#  6   Passed                                       38000 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 2.1+ MB

# %%
from ydata_profiling import ProfileReport

report= ProfileReport(df,title='data report')

# %%
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.18.1&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-04-05 18:36:13.453782&quot; name=date&gt;&lt;title&gt;data report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
df.head()
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
# 3     S00004                  17.6             76.8             62.4
# 4     S00005                   8.8             89.3             72.7
#
#   Participation in Extracurricular Activities Parent Education Level Passed
# 0                                         Yes                 Master    Yes
# 1                                          No            High School     No
# 2                                          No              Associate     No
# 3                                         Yes               Bachelor     No
# 4                                          No                 Master     No

# %% [markdown]
# # target - passed
# # input - previous grades , study hour ,attendance rate

# %%
df.describe()
# Out:
#        Study Hours per Week  Attendance Rate  Previous Grades
# count          38005.000000     38008.000000     38006.000000
# mean               9.962744        75.276323        65.440107
# std                5.031154        20.393418        16.503119
# min              -12.300000       -14.300000         8.300000
# 25%                6.600000        61.600000        55.100000
# 50%               10.000000        75.300000        65.200000
# 75%               13.400000        88.800000        75.200000
# max               32.400000       150.200000       200.000000

# %%
df['Study Hours per Week'].min()
# Out:
# -12.3

# %%
# y=df['Passed']

# %%
df=df[['Study Hours per Week','Attendance Rate','Previous Grades','Passed','Participation in Extracurricular Activities']]

# %%
df.columns
# Out:
# Index(['Study Hours per Week', 'Attendance Rate', 'Previous Grades', 'Passed',
#        'Participation in Extracurricular Activities'],
#       dtype='object')

# %%
num_cols = df.select_dtypes(include=['number'])
df=df[((num_cols > 0) &  (num_cols <=100)).all(axis=1)]

# %%
df.describe()
# Out:
#        Study Hours per Week  Attendance Rate  Previous Grades
# count          29419.000000     29419.000000     29419.000000
# mean              10.258190        71.028315        64.667249
# std                4.704348        16.801187        14.525116
# min                0.100000         0.500000         8.300000
# 25%                6.900000        59.800000        54.900000
# 50%               10.100000        72.500000        65.000000
# 75%               13.500000        84.000000        74.700000
# max               32.400000       100.000000       100.000000

# %%
# df=df[df['Attendance Rate']<=100]

# %%
# df.describe()

# %%
# df=df[df['Previous Grades']<=100]

# %%
# df.describe()

# %%
# y.isna().sum()

# %%
# y.unique()

# %%
# y=y.fillna(y.mode()[0])

# %%
# y.count()

# %%
df.count()
# Out:
# Study Hours per Week                           29419
# Attendance Rate                                29419
# Previous Grades                                29419
# Passed                                         27938
# Participation in Extracurricular Activities    27937
# dtype: int64

# %%
df.columns
# Out:
# Index(['Study Hours per Week', 'Attendance Rate', 'Previous Grades', 'Passed',
#        'Participation in Extracurricular Activities'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29419 entries, 1 to 39999
# Data columns (total 5 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Study Hours per Week                         29419 non-null  float64
#  1   Attendance Rate                              29419 non-null  float64
#  2   Previous Grades                              29419 non-null  float64
#  3   Passed                                       27938 non-null  object
#  4   Participation in Extracurricular Activities  27937 non-null  object
# dtypes: float64(3), object(2)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#        Study Hours per Week  Attendance Rate  Previous Grades
# count          29419.000000     29419.000000     29419.000000
# mean              10.258190        71.028315        64.667249
# std                4.704348        16.801187        14.525116
# min                0.100000         0.500000         8.300000
# 25%                6.900000        59.800000        54.900000
# 50%               10.100000        72.500000        65.000000
# 75%               13.500000        84.000000        74.700000
# max               32.400000       100.000000       100.000000

# %%
df['Passed'].isnull().sum()
# Out:
# np.int64(1481)

# %%
df['Passed'].count()
# Out:
# np.int64(27938)

# %%
df['Passed']=df['Passed'].fillna(df['Passed'].mode()[0])

# %%
df['Passed'].count()
# Out:
# np.int64(29419)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29419 entries, 1 to 39999
# Data columns (total 5 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Study Hours per Week                         29419 non-null  float64
#  1   Attendance Rate                              29419 non-null  float64
#  2   Previous Grades                              29419 non-null  float64
#  3   Passed                                       29419 non-null  object
#  4   Participation in Extracurricular Activities  27937 non-null  object
# dtypes: float64(3), object(2)
# memory usage: 1.3+ MB

# %%
df['Study Hours per Week'].unique()
# Out:
# array([ 9.3, 17.6,  8.8, 17.9, 13.8, 12.7,  7.7, 11.2,  0.4,  1.4,  7.2,
#         4.9, 11.6,  5.5,  2.9,  8.9, 10.3,  7.3, 11.9,  7. ,  8.5, 19.3,
#         9.9,  4.7, 14.1,  3.9, 11. ,  0.2,  3.4, 10.9,  2.6,  6.4, 15.3,
#        11.7,  8.1,  6.6, 15.2, 14.7, 14.9,  7.6,  9.1,  4.5,  4. , 16.8,
#         9.6, 15. , 11.8, 17.7,  9.8, 17.8, 10.4, 10.5,  0.1,  6. ,  7.5,
#        14.6,  7.4, 12.6,  6.5,  8.4, 11.5, 10. ,  7.9,  9.2, 12. , 19.4,
#        22.3,  9. ,  4.2, 15.7, 14. , 17. , 21. ,  2.2, 12.4,  5.4,  6.1,
#         3.8, 11.1, 16.5,  2. , 11.3, 13.9,  5.1, 15.8, 14.8, 12.1,  6.2,
#         5.6, 11.4, 10.1, 17.3,  8.7, 13.1,  5.7,  2.4,  7.8, 14.3, 10.8,
#        12.8, 15.4,  3.1,  5.3, 13.3, 21.6, 13.4,  1.9,  4.6, 10.2,  6.7,
#        20.7,  9.4, 12.5,  8.3, 18.8,  3.7, 20.6, 16.3, 12.2,  9.7, 18.2,
#         2.8, 10.7, 17.2, 12.3, 10.6, 12.9,  6.9,  7.1, 14.2, 14.5, 13.7,
#        16.4, 15.5, 13. ,  5.9, 20.5,  3. , 17.4,  5. ,  8.6,  9.5, 13.5,
# ...

# %%
df['performance_score'] = (
    df['Study Hours per Week'] * 0.3 +
    df['Attendance Rate'] * 0.3 +
    df['Previous Grades'] * 0.4
)
df
# Out:
#        Study Hours per Week  Attendance Rate  Previous Grades Passed  \
# 1                       9.3             95.3             60.6     No
# 3                      17.6             76.8             62.4     No
# 4                       8.8             89.3             72.7     No
# 5                       8.8             73.8             69.3    Yes
# 6                      17.9             38.6             93.6    Yes
# ...                     ...              ...              ...    ...
# 39994                   5.1             92.1             46.1     No
# 39995                  15.6             93.8             51.4     No
# 39996                  11.3             66.4             64.2    Yes
# 39997                  13.1             65.6             38.1     No
# 39999                  11.8             55.1             68.5    Yes
#
#       Participation in Extracurricular Activities  performance_score
# 1                                              No              55.62
# ...

# %%
df['Participation in Extracurricular Activities'].isna().sum()
df['activity']=df['Participation in Extracurricular Activities']

# %%
df['activity']=df['activity'].fillna(df['activity'].mode()[0])
df.isnull().sum()
# Out:
# Study Hours per Week                              0
# Attendance Rate                                   0
# Previous Grades                                   0
# Passed                                            0
# Participation in Extracurricular Activities    1482
# performance_score                                 0
# activity                                          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn.ensemble import  RandomForestClassifier
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
df.columns
x=df[['Study Hours per Week', 'Attendance Rate', 'Previous Grades','performance_score','activity']]
y=df['Passed']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2 , random_state=42)

# %%
# x_train,x_val,y_train,y_val = train_test_split(x_train,y_train, test_size=0.1 , random_state=42)

# %%
x_train.count()
# Out:
# Study Hours per Week    23535
# Attendance Rate         23535
# Previous Grades         23535
# performance_score       23535
# activity                23535
# dtype: int64

# %%
x_test.count()
# Out:
# Study Hours per Week    5884
# Attendance Rate         5884
# Previous Grades         5884
# performance_score       5884
# activity                5884
# dtype: int64

# %%
# x_val.count()

# %%
le=LabelEncoder()
y_train=le.fit_transform(y_train)
# y_val=le.fit_transform(y_val)
y_test=le.fit_transform(y_test)

# %%
# oneHot_enco=OneHotEncoder()
# x_train['activity']=oneHot_enco.fit_transform(x_train[['activity']])
# x_val['activity']=oneHot_enco.fit_transform(x_val[['activity']])
# x_test['activity']=oneHot_enco.fit_transform(x_test[['activity']])



x_train['activity'] = x_train['activity'].map({'Yes': 1, 'No': 0})
# x_val['activity']   = x_val['activity'].map({'Yes': 1, 'No': 0})
x_test['activity']  = x_test['activity'].map({'Yes': 1, 'No': 0})

# %%
model=RandomForestClassifier(n_estimators=400, max_depth=20, random_state=42 , min_samples_leaf=20,min_samples_split=5)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=20, min_samples_split=5,
#                        n_estimators=400, random_state=42)

# %%
pred=model.predict(x_val)

# %%
accuracy_score(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 accuracy_score(y_test,pred)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
m=LogisticRegression(class_weight='balanced')

# %%
m.fit(x_train,y_train)

# %%
pr=m.predict(x_test)

# %%
accuracy_score(y_test,pred)

# %%
x_train

# %%
y_train

# %%
importance = pd.Series(model.feature_importances_, index=x.columns)
print(importance)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=5)
model.fit(x_train, y_train)

print(accuracy_score(y_test, model.predict(x_test)))

# %%
x_train['activity'].unique()
